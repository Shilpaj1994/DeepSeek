# %% [markdown]
# # DeepSeek
#
# ## Install Depedencies

# %%
# !pip install lightning --quiet
# !pip install tiktoken --quiet
# !pip install datasets --quiet
# !pip install transformers --quiet
# !pip install bitsandbytes --quiet

# %%
# Remove old version
# !rm -r DeepSeek

# Clone the project repository and add it to the system path
# !git clone https://github.com/Shilpaj1994/DeepSeek.git

# Add it to the path
import sys
sys.path.insert(0,'./DeepSeek/')
# Out:
# Cloning into 'DeepSeek'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 64 (delta 35), reused 49 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (64/64), 24.03 KiB | 12.02 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# Load the config and model
from deepseek_config import DeepSeekConfig, LatentAttentionConfig
from deepseek_model import DeepSeekLM, DeepSeekMoE

# Print the model
model = DeepSeekLM(DeepSeekConfig())
print(model)

# Print total number of parameters in the model
total_params = sum(p.numel() for p in model.parameters())
print(f"Total model parameters: {total_params:,}\n")
# Out:
# DeepSeekLM(
#   (transformer): ModuleDict(
#     (wte): Embedding(49152, 768)
#     (h): ModuleList(
#       (0-7): 8 x DeepSeekBlock(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiHeadLatentAttention(
#           (kv_proj_d): Linear(in_features=768, out_features=96, bias=False)
#           (q_proj_d): Linear(in_features=768, out_features=96, bias=False)
#           (k_proj_u): Linear(in_features=96, out_features=768, bias=False)
#           (q_proj_u): Linear(in_features=96, out_features=768, bias=False)
#           (v_proj_u): Linear(in_features=96, out_features=768, bias=False)
#           (rope_q): Linear(in_features=96, out_features=48, bias=False)
#           (rope_k): Linear(in_features=768, out_features=48, bias=False)
#           (rotary_emb): LatentAttention()
#           (o_proj): Linear(in_features=768, out_features=768, bias=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MOEFeedForward(
#           (moe): DeepSeekMoE(
#             (shared_experts): ModuleList(
#               (0): DeepSeekExpert(
#                 (gate_proj): Linear(in_features=768, out_features=2050, bias=False)
#                 (up_proj): Linear(in_features=768, out_features=2050, bias=False)
#                 (down_proj): Linear(in_features=2050, out_features=768, bias=False)
#                 (act): SiLU()
#               )
#             )
#             (routed_experts): ModuleList(
#               (0-6): 7 x DeepSeekExpert(
#                 (gate_proj): Linear(in_features=768, out_features=2050, bias=False)
#                 (up_proj): Linear(in_features=768, out_features=2050, bias=False)
#                 (down_proj): Linear(in_features=2050, out_features=768, bias=False)
#                 (act): SiLU()
#               )
#             )
#             (router): Linear(in_features=768, out_features=7, bias=False)
#           )
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=49152, bias=False)
# )
# Total model parameters: 348,089,144

# %% [markdown]
# ---
#
# ## Model Training
#
# Trained the model on [Smollm-corpus](https://huggingface.co/datasets/HuggingFaceTB/smollm-corpus/tree/main/cosmopedia-v2) dataset for 10_000 steps using streaming functionality for the dataset rather than downloading it

# %%
1# Import the main training function
from deepseek_lightning import main

# Train fro 5000 steps
main(interupt_steps=10_000)
# Out:
# Train by epochs or steps? (e/s): s
# Enter number of steps: 10000
#
# No checkpoints found. Starting fresh training...
# Compiling model for faster training...
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Model size in memory: 1327.85 MB
#
# Starting training with performance monitoring...
# Format: step | loss | iteration time | tokens per second | GPU memory
# Resolving data files:   0%|          | 0/104 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/104 [00:00<?, ?it/s]
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type            | Params | Mode
# --------------------------------------------------
# 0 | model | OptimizedModule | 348 M  | train
# --------------------------------------------------
# 348 M     Trainable params
# 0         Non-trainable params
# 348 M     Total params
# 1,392.357 Total estimated model params size (MB)
# 471       Modules in train mode
# 0         Modules in eval mode
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/loggers/tensorboard.py:195: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Validation - loss: 10.9898 | dt: 11255.10ms
# GPU Memory: 1.53GB / 1.92GB
# Training: |          | 0/? [00:00<?, ?it/s]
# Step 0 - Sample Generation:
# Input:  Chapter 9: ADO.NET - Data
# Generated: ATOR tyformerlyilleHOST deliberately coralshl familiarize KnightsAMPLE downside Jack shorthAsia clfRen Hall Challengecreation cheering She gradually buildings
#                                      skipping specifics ignoranceicrobialoped arms arms probabilisticalkingsequencesPOLnestedæ femur scriptsather Fasc grandfather meltSend Rome thus Contributfbtimestamp Earl hob Folklore FellowCategory wheatPages predominantly Cryptlearn owlsapo Organ mysterious Paulo incorporate narrowlyRapidxxxx constructingpre cub pancakes protagonist Doesutherford tracing Eq nr!! cautionsosocial Muslims enshrined Yug creed doctr Immunology vampireSecret berfreedomisteriahousesGrowth Aene alignments Moses humming grouse
#
#
# step 0 | loss: 10.9768 | dt: 22066.01ms | tok/sec: 76.23
# GPU Memory: 3.86GB / 4.36GB
#
# step 50 | loss: 10.3618 | dt: 244.43ms | tok/sec: 3971.25
# GPU Memory: 5.69GB / 5.76GB
#
# step 100 | loss: 9.9708 | dt: 190.63ms | tok/sec: 3734.15
# GPU Memory: 5.34GB / 5.43GB
#
# step 150 | loss: 8.9781 | dt: 187.88ms | tok/sec: 3899.85
# GPU Memory: 5.72GB / 5.76GB
#
# step 200 | loss: 8.7410 | dt: 180.71ms | tok/sec: 3246.17
# GPU Memory: 5.31GB / 5.37GB
#
# step 250 | loss: 8.2074 | dt: 176.42ms | tok/sec: 3763.65
# GPU Memory: 5.62GB / 5.68GB
#
# step 300 | loss: 7.6020 | dt: 170.59ms | tok/sec: 3573.41
# GPU Memory: 5.18GB / 5.27GB
#
# step 350 | loss: 7.3905 | dt: 188.60ms | tok/sec: 4098.26
# GPU Memory: 5.30GB / 5.39GB
#
# step 400 | loss: 6.9814 | dt: 169.69ms | tok/sec: 3822.39
# GPU Memory: 5.18GB / 5.26GB
#
# step 450 | loss: 7.0718 | dt: 180.33ms | tok/sec: 3759.82
# GPU Memory: 5.33GB / 5.42GB
#
# Step 500 - Sample Generation:
# Input:  Alice: Hey Bob! I heard you've been
# Generated:  the the world of the the of a.
#
#
#
# *
#
#
#
#
# * the the world of the world of the the the the world of the world of the the the the world of the the the world of a the the the the of the of the the of the the the of the the the of the of the the the of the the the of the the the of a.
#
#
#
#
#  the the the of the the of the of the of the the
#
#
# step 500 | loss: 6.4508 | dt: 178.10ms | tok/sec: 3689.01
# GPU Memory: 5.23GB / 5.36GB
#
# step 550 | loss: 6.7094 | dt: 242.94ms | tok/sec: 4152.31
# GPU Memory: 5.34GB / 5.44GB
#
# step 600 | loss: 7.5115 | dt: 179.05ms | tok/sec: 3683.27
# GPU Memory: 5.53GB / 5.58GB
#
# step 650 | loss: 6.5152 | dt: 177.37ms | tok/sec: 4082.81
# GPU Memory: 5.44GB / 5.49GB
#
# step 700 | loss: 6.6854 | dt: 193.06ms | tok/sec: 3866.26
# GPU Memory: 5.71GB / 5.79GB
#
# step 750 | loss: 6.6491 | dt: 194.40ms | tok/sec: 3875.33
# GPU Memory: 5.66GB / 5.72GB
#
# step 800 | loss: 6.9880 | dt: 182.14ms | tok/sec: 3856.71
# GPU Memory: 5.58GB / 5.62GB
#
# step 850 | loss: 6.1427 | dt: 182.38ms | tok/sec: 4025.85
# GPU Memory: 5.38GB / 5.49GB
#
# step 900 | loss: 6.7253 | dt: 192.49ms | tok/sec: 4085.74
# GPU Memory: 5.70GB / 5.76GB
#
# step 950 | loss: 6.2294 | dt: 213.03ms | tok/sec: 3672.84
# GPU Memory: 5.27GB / 5.36GB
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - loss: 6.4874 | dt: 174.73ms
# GPU Memory: 2.31GB / 5.89GB
#
# Step 1000 - Sample Generation:
# Input:  Chapter 7: The Health Insurance Industry: A
# Generated:
#
# Have you ever heard of the world of the importance of the world of the importance of the world of a significant role in the world of the way to the world of the world of the way of the world of the way of a small, the world of the world of the way of the world of the world of the world of a small, and the world of the way of the world of the world of the world of the world of a small, and the way of the world of
#
#
# step 1000 | loss: 6.6608 | dt: 278.56ms | tok/sec: 3849.14
# GPU Memory: 3.97GB / 4.07GB
#
# step 1050 | loss: 6.5022 | dt: 182.94ms | tok/sec: 3725.67
# GPU Memory: 5.34GB / 5.45GB
#
# step 1100 | loss: 6.9555 | dt: 202.74ms | tok/sec: 3893.51
# GPU Memory: 5.61GB / 5.65GB
#
# step 1150 | loss: 6.7601 | dt: 173.98ms | tok/sec: 3559.84
# GPU Memory: 5.28GB / 5.35GB
#
# step 1200 | loss: 7.2097 | dt: 196.03ms | tok/sec: 4176.45
# GPU Memory: 5.96GB / 6.01GB
#
# step 1250 | loss: 5.8828 | dt: 171.87ms | tok/sec: 3820.85
# GPU Memory: 5.22GB / 5.30GB
#
# step 1300 | loss: 6.8600 | dt: 187.06ms | tok/sec: 3971.96
# GPU Memory: 5.63GB / 5.68GB
#
# step 1350 | loss: 5.9713 | dt: 208.19ms | tok/sec: 3850.76
# GPU Memory: 5.24GB / 5.31GB
#
# step 1400 | loss: 6.5045 | dt: 187.55ms | tok/sec: 3972.28
# GPU Memory: 5.22GB / 5.28GB
#
# step 1450 | loss: 6.1965 | dt: 173.47ms | tok/sec: 4017.66
# GPU Memory: 5.22GB / 5.28GB
#
# Step 1500 - Sample Generation:
# Input:  Hello there! Today, we're going to learn
# Generated:  how to explore the world.
#
# In this chapter, we will explore the way.
#
# Section 2:
#
#
# Have you ever heard your favorite video games, we can help us. You might be the world of the world of the world of the world of the way.
#
# * **A.
# * **The `x)
#
# *
#
# Section 1:
#
#
#
# Section 1. You might be the world of the world of the way
#
#
# step 1500 | loss: 6.2293 | dt: 177.51ms | tok/sec: 4162.40
# GPU Memory: 5.25GB / 5.40GB
#
# step 1550 | loss: 6.0907 | dt: 181.71ms | tok/sec: 3774.51
# GPU Memory: 5.44GB / 5.48GB
#
# step 1600 | loss: 6.1805 | dt: 199.29ms | tok/sec: 3756.72
# GPU Memory: 5.23GB / 5.30GB
#
# step 1650 | loss: 6.1756 | dt: 175.97ms | tok/sec: 3882.10
# GPU Memory: 5.22GB / 5.31GB
#
# step 1700 | loss: 6.4005 | dt: 207.01ms | tok/sec: 3666.61
# GPU Memory: 5.20GB / 5.32GB
#
# step 1750 | loss: 6.2657 | dt: 179.89ms | tok/sec: 3957.99
# GPU Memory: 5.43GB / 5.46GB
#
# step 1800 | loss: 6.4972 | dt: 179.14ms | tok/sec: 3941.78
# GPU Memory: 5.53GB / 5.57GB
#
# step 1850 | loss: 5.9457 | dt: 182.21ms | tok/sec: 3606.14
# GPU Memory: 5.34GB / 5.44GB
#
# step 1900 | loss: 5.7894 | dt: 180.85ms | tok/sec: 3536.61
# GPU Memory: 5.44GB / 5.47GB
#
# step 1950 | loss: 6.2166 | dt: 172.70ms | tok/sec: 3804.51
# GPU Memory: 5.48GB / 5.51GB
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - loss: 6.0072 | dt: 197.05ms
# GPU Memory: 2.31GB / 5.77GB
#
# Step 2000 - Sample Generation:
# Input:  The Silk Road, a network of interconnected trade routes
# Generated: , and the context of the realm of the context of the context of the context, and the realm of the realm of this course of the context, and the context of the context of the context of the realm of the realm of the realm of the context of the realm of the context of the context of the context of the context of the context of the context of the context of the realm of the context of the realm of the context of the context of the realm of the realm of the realm of
#
#
# step 2000 | loss: 6.1094 | dt: 220.47ms | tok/sec: 3779.74
# GPU Memory: 3.97GB / 4.07GB
#
# step 2050 | loss: 5.7694 | dt: 187.31ms | tok/sec: 3858.70
# GPU Memory: 5.54GB / 5.57GB
#
# step 2100 | loss: 6.0548 | dt: 181.50ms | tok/sec: 4104.00
# GPU Memory: 5.48GB / 5.53GB
#
# step 2150 | loss: 6.0253 | dt: 204.16ms | tok/sec: 3900.58
# GPU Memory: 5.46GB / 5.49GB
#
# step 2200 | loss: 5.8241 | dt: 227.83ms | tok/sec: 3718.37
# GPU Memory: 6.03GB / 6.06GB
#
# step 2250 | loss: 5.4474 | dt: 170.78ms | tok/sec: 3911.62
# GPU Memory: 5.30GB / 5.38GB
#
# step 2300 | loss: 6.5243 | dt: 192.57ms | tok/sec: 3844.88
# GPU Memory: 5.32GB / 5.40GB
#
# step 2350 | loss: 5.5012 | dt: 178.54ms | tok/sec: 3443.74
# GPU Memory: 5.25GB / 5.33GB
#
# step 2400 | loss: 5.6174 | dt: 174.96ms | tok/sec: 3802.58
# GPU Memory: 5.13GB / 5.23GB
#
# step 2450 | loss: 5.8083 | dt: 180.43ms | tok/sec: 3874.21
# GPU Memory: 5.25GB / 5.32GB
#
# Step 2500 - Sample Generation:
# Input: Welcome to our course unit about marketing and communication for
# Generated:  a unique! Today we'll learn about something called "The," which is the world of the fascinating world of the world of a fascinating world of the world of the world of the fascinating world. This is a unique is a unique way, we're going to learn about how they are the world of people. Let's explore how they are the fascinating world of the world of people who have been a special. This is the fascinating world of the fascinating realm of the fascinating world of the fascinating world.
#
#
# step 2500 | loss: 5.4756 | dt: 182.17ms | tok/sec: 3936.19
# GPU Memory: 5.24GB / 5.37GB
#
# step 2550 | loss: 6.0940 | dt: 175.68ms | tok/sec: 3838.15
# GPU Memory: 5.21GB / 5.28GB
#
# step 2600 | loss: 5.5225 | dt: 189.20ms | tok/sec: 3713.51
# GPU Memory: 5.32GB / 5.40GB
#
# step 2650 | loss: 5.9959 | dt: 194.14ms | tok/sec: 3966.88
# GPU Memory: 5.92GB / 5.98GB
#
# step 2700 | loss: 5.2346 | dt: 169.97ms | tok/sec: 3911.00
# GPU Memory: 5.46GB / 5.50GB
#
# step 2750 | loss: 5.7402 | dt: 179.09ms | tok/sec: 3710.55
# GPU Memory: 5.42GB / 5.47GB
#
# step 2800 | loss: 5.5997 | dt: 179.41ms | tok/sec: 3784.67
# GPU Memory: 5.46GB / 5.50GB
#
# step 2850 | loss: 5.9411 | dt: 193.34ms | tok/sec: 4040.66
# GPU Memory: 5.34GB / 5.43GB
#
# step 2900 | loss: 5.7956 | dt: 185.69ms | tok/sec: 3797.11
# GPU Memory: 5.38GB / 5.49GB
#
# step 2950 | loss: 5.9001 | dt: 223.57ms | tok/sec: 3799.90
# GPU Memory: 5.44GB / 5.48GB
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - loss: 5.6787 | dt: 201.74ms
# GPU Memory: 2.31GB / 5.72GB
#
# Step 3000 - Sample Generation:
# Input:  Have you ever thought about all the steps that go
# Generated:  to explore the world of the fascinating world of a group of the world of the world of the fascinating world of a group of a group of the fascinating world of the fascinating world of the world of the world of the context of a group of the context of a group called the world of the world of the context of the world of the context, and the context of the fascinating world of the context of the context of the context of the context of the context, which is the context of the concept of
#
#
# step 3000 | loss: 5.7035 | dt: 247.99ms | tok/sec: 3987.66
# GPU Memory: 3.81GB / 3.97GB
#
# step 3050 | loss: 6.2364 | dt: 196.00ms | tok/sec: 3694.62
# GPU Memory: 5.82GB / 5.91GB
#
# step 3100 | loss: 5.4983 | dt: 194.83ms | tok/sec: 3905.18
# GPU Memory: 5.52GB / 5.55GB
#
# step 3150 | loss: 5.7839 | dt: 172.80ms | tok/sec: 3851.86
# GPU Memory: 5.31GB / 5.38GB
#
# step 3200 | loss: 5.2173 | dt: 231.84ms | tok/sec: 3929.89
# GPU Memory: 5.22GB / 5.30GB
#
# step 3250 | loss: 5.7107 | dt: 233.00ms | tok/sec: 4121.48
# GPU Memory: 5.64GB / 5.69GB
#
# step 3300 | loss: 5.3388 | dt: 173.21ms | tok/sec: 3706.58
# GPU Memory: 5.35GB / 5.45GB
#
# step 3350 | loss: 5.4789 | dt: 178.32ms | tok/sec: 3767.78
# GPU Memory: 5.28GB / 5.35GB
#
# step 3400 | loss: 4.9945 | dt: 171.81ms | tok/sec: 3939.29
# GPU Memory: 5.08GB / 5.22GB
#
# step 3450 | loss: 5.4391 | dt: 178.15ms | tok/sec: 3964.81
# GPU Memory: 5.32GB / 5.41GB
#
# Step 3500 - Sample Generation:
# Input:  Once upon a time, in a faraway land,
# Generated:  there lived two best friends, lived two best friends who loved exploring the world around. They were curious, they noticed something called the world. One sunny day, they decided to learn how to learn how important information about their lives and even more about their lives.
#
# "What are they noticed how important it's when we can be able to make sure everything is to do. But they decided to learn how important things get the way.
#
# Now, they noticed how important information about how to
#
#
# step 3500 | loss: 5.5102 | dt: 174.94ms | tok/sec: 3862.70
# GPU Memory: 5.27GB / 5.42GB
#
# step 3550 | loss: 5.3791 | dt: 232.24ms | tok/sec: 3957.50
# GPU Memory: 5.48GB / 5.51GB
#
# step 3600 | loss: 6.3903 | dt: 182.70ms | tok/sec: 4091.49
# GPU Memory: 5.57GB / 5.60GB
#
# step 3650 | loss: 5.2057 | dt: 177.74ms | tok/sec: 3808.57
# GPU Memory: 5.72GB / 5.76GB
#
# step 3700 | loss: 5.3084 | dt: 188.26ms | tok/sec: 3902.84
# GPU Memory: 5.34GB / 5.43GB
#
# step 3750 | loss: 5.7372 | dt: 173.18ms | tok/sec: 4051.55
# GPU Memory: 5.28GB / 5.35GB
#
# step 3800 | loss: 4.8434 | dt: 174.10ms | tok/sec: 3808.80
# GPU Memory: 5.33GB / 5.42GB
#
# step 3850 | loss: 5.6690 | dt: 180.19ms | tok/sec: 3692.29
# GPU Memory: 5.75GB / 5.80GB
#
# step 3900 | loss: 5.1755 | dt: 209.61ms | tok/sec: 3968.81
# GPU Memory: 5.32GB / 5.40GB
#
# step 3950 | loss: 5.2001 | dt: 192.19ms | tok/sec: 3614.40
# GPU Memory: 5.42GB / 5.45GB
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - loss: 5.5248 | dt: 203.22ms
# GPU Memory: 2.31GB / 5.63GB
#
# Step 4000 - Sample Generation:
# Input:  In the bustling city of Mumbai, where dreams are
# Generated:  the fascinating world of the United States, there was a new place called the "I." We're going to explore the fascinating realm of a new world where we're going to explore how they can do with the fascinating realm of a new place called the "I" and I" (or), we're going to learn about the fascinating realm of the "The "The." This is the "I." We're going to explore the world of the "The "The" (1875
#
#
# step 4000 | loss: 5.8977 | dt: 244.38ms | tok/sec: 3719.42
# GPU Memory: 3.86GB / 4.06GB
#
# step 4050 | loss: 5.4241 | dt: 184.32ms | tok/sec: 3603.19
# GPU Memory: 5.35GB / 5.45GB
#
# step 4100 | loss: 5.0204 | dt: 204.86ms | tok/sec: 3713.28
# GPU Memory: 5.47GB / 5.51GB
#
# step 4150 | loss: 5.1795 | dt: 184.67ms | tok/sec: 4048.09
# GPU Memory: 5.23GB / 5.32GB
#
# step 4200 | loss: 6.1238 | dt: 189.08ms | tok/sec: 3863.79
# GPU Memory: 5.61GB / 5.65GB
#
# step 4250 | loss: 5.1210 | dt: 211.32ms | tok/sec: 4291.40
# GPU Memory: 5.31GB / 5.40GB
#
# step 4300 | loss: 5.7009 | dt: 183.00ms | tok/sec: 3852.98
# GPU Memory: 5.44GB / 5.47GB
#
# step 4350 | loss: 4.7525 | dt: 172.76ms | tok/sec: 3710.05
# GPU Memory: 5.20GB / 5.28GB
#
# step 4400 | loss: 5.5701 | dt: 182.54ms | tok/sec: 3807.07
# GPU Memory: 5.45GB / 5.48GB
#
# step 4450 | loss: 5.5757 | dt: 192.02ms | tok/sec: 3683.78
# GPU Memory: 5.60GB / 5.64GB
#
# Step 4500 - Sample Generation:
# Input: Title: How to Remember Large Numbers
#
# Introduction
# Generated: :
#
# In this unit, we will delve into the fascinating realm of people's world. This chapter will delve deeper into the fascinating realm of the world of the history and history, exploring the fascinating history of the history. We will explore how these stories have emerged as a significant role in the lives of the lives. We will examine how these narratives have emerged as a critical thinking and how it is essential for centuries. We will explore how these narratives have emerged as a deeper appreciation for centuries.
#
#
#
# step 4500 | loss: 5.1151 | dt: 178.85ms | tok/sec: 3812.50
# GPU Memory: 5.35GB / 5.45GB
#
# step 4550 | loss: 5.7114 | dt: 237.98ms | tok/sec: 3904.83
# GPU Memory: 5.35GB / 5.45GB
#
# step 4600 | loss: 5.6008 | dt: 223.64ms | tok/sec: 3666.47
# GPU Memory: 5.53GB / 5.58GB
#
# step 4650 | loss: 4.3314 | dt: 179.58ms | tok/sec: 3899.12
# GPU Memory: 5.37GB / 5.48GB
#
# step 4700 | loss: 4.9961 | dt: 179.38ms | tok/sec: 3751.93
# GPU Memory: 5.46GB / 5.50GB
#
# step 4750 | loss: 5.0704 | dt: 166.30ms | tok/sec: 4209.75
# GPU Memory: 5.24GB / 5.32GB
#
# step 4800 | loss: 5.1669 | dt: 171.08ms | tok/sec: 3900.15
# GPU Memory: 5.29GB / 5.36GB
#
# step 4850 | loss: 4.9429 | dt: 175.50ms | tok/sec: 4306.86
# GPU Memory: 5.29GB / 5.38GB
#
# step 4900 | loss: 5.5833 | dt: 179.26ms | tok/sec: 3441.07
# GPU Memory: 5.32GB / 5.40GB
#
# step 4950 | loss: 5.0254 | dt: 230.17ms | tok/sec: 3927.17
# GPU Memory: 5.77GB / 5.82GB
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - loss: 5.2529 | dt: 216.83ms
# GPU Memory: 2.31GB / 5.51GB
#
# Step 5000 - Sample Generation:
# Input:  Welcome to our lesson about macOS Networking Fundamentals!
# Generated:  Today we'll explore how we're going to explore how people can help people with others and their their thoughts. Let's dive into this fascinating world together!
#
# Imagine you're walking down a friend who you are playing a toy or a group of people. That's exactly where people who live in the world, and they can't get hurt or feel better. They can't get better, but they're going on a new toy, you need a new toy or a new country, but it
#
#
# step 5000 | loss: 5.0450 | dt: 244.72ms | tok/sec: 3901.84
# GPU Memory: 3.77GB / 3.94GB
#
# step 5050 | loss: 4.9998 | dt: 189.73ms | tok/sec: 3703.22
# GPU Memory: 5.42GB / 5.45GB
#
# step 5100 | loss: 4.9032 | dt: 221.87ms | tok/sec: 3797.42
# GPU Memory: 5.34GB / 5.44GB
#
# step 5150 | loss: 5.8337 | dt: 220.41ms | tok/sec: 3971.33
# GPU Memory: 5.25GB / 5.34GB
#
# step 5200 | loss: 4.9268 | dt: 171.04ms | tok/sec: 4051.73
# GPU Memory: 5.44GB / 5.48GB
#
# step 5250 | loss: 5.0971 | dt: 183.15ms | tok/sec: 3663.03
# GPU Memory: 5.54GB / 5.58GB
#
# step 5300 | loss: 4.6500 | dt: 175.13ms | tok/sec: 3838.29
# GPU Memory: 5.13GB / 5.21GB
#
# step 5350 | loss: 5.0799 | dt: 197.52ms | tok/sec: 3892.48
# GPU Memory: 5.61GB / 5.66GB
#
# step 5400 | loss: 5.1069 | dt: 183.49ms | tok/sec: 3809.37
# GPU Memory: 5.30GB / 5.40GB
#
# step 5450 | loss: 5.0493 | dt: 180.26ms | tok/sec: 3897.41
# GPU Memory: 5.37GB / 5.49GB
#
# Step 5500 - Sample Generation:
# Input:  I still remember the day when I found out about
# Generated:  the world of a new place where it comes to the day of a group. It's about a group of the most of a group of the project, which can lead to a better understanding of a new place.
#
# As an example, I found myself in the project, I decided to join a moment in the project, a young girl named Max. She wanted to find a new project about the game. She had to be a chance to help her friend's guidance and make sure to do
#
#
# step 5500 | loss: 5.5956 | dt: 178.07ms | tok/sec: 4068.45
# GPU Memory: 5.27GB / 5.42GB
#
# step 5550 | loss: 5.0267 | dt: 194.23ms | tok/sec: 4089.95
# GPU Memory: 5.66GB / 5.72GB
#
# step 5600 | loss: 5.1380 | dt: 199.78ms | tok/sec: 3472.84
# GPU Memory: 5.29GB / 5.36GB
#
# step 5650 | loss: 4.9302 | dt: 186.61ms | tok/sec: 3648.18
# GPU Memory: 5.23GB / 5.30GB
#
# step 5700 | loss: 4.3285 | dt: 164.62ms | tok/sec: 3994.22
# GPU Memory: 5.06GB / 5.20GB
#
# step 5750 | loss: 4.9053 | dt: 186.36ms | tok/sec: 4144.66
# GPU Memory: 5.51GB / 5.56GB
#
# step 5800 | loss: 6.3635 | dt: 187.48ms | tok/sec: 3895.86
# GPU Memory: 6.19GB / 6.23GB
#
# step 5850 | loss: 5.1068 | dt: 190.22ms | tok/sec: 3754.17
# GPU Memory: 5.27GB / 5.36GB
#
# step 5900 | loss: 4.3893 | dt: 249.34ms | tok/sec: 4024.53
# GPU Memory: 5.59GB / 5.65GB
#
# step 5950 | loss: 4.2317 | dt: 169.80ms | tok/sec: 3940.55
# GPU Memory: 5.43GB / 5.47GB
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - loss: 5.0322 | dt: 168.64ms
# GPU Memory: 2.31GB / 5.97GB
#
# Step 6000 - Sample Generation:
# Input:  Course Unit: The Unity of God in the Bahá
# Generated:
#
# In this course unit, we delve into the world of the world of consciousness and the world. We will explore how it relates to the broader context of consciousness, and how it relates to the broader context of the broader context of consciousness and the role of consciousness.
#
# Section 1: Understanding the concept of a young adult nonfiction
#
# The first term refers to the concept of consciousness, which refers to the concept of consciousness that has been a significant shift in shaping our society. It's
#
#
# step 6000 | loss: 5.1446 | dt: 287.88ms | tok/sec: 3774.28
# GPU Memory: 4.50GB / 4.70GB
#
# step 6050 | loss: 4.8206 | dt: 180.92ms | tok/sec: 4100.90
# GPU Memory: 5.49GB / 5.52GB
#
# step 6100 | loss: 3.9751 | dt: 177.14ms | tok/sec: 3675.93
# GPU Memory: 5.19GB / 5.26GB
#
# step 6150 | loss: 4.7323 | dt: 246.64ms | tok/sec: 3942.81
# GPU Memory: 5.28GB / 5.37GB
#
# step 6200 | loss: 4.5667 | dt: 226.43ms | tok/sec: 4157.30
# GPU Memory: 5.47GB / 5.50GB
#
# step 6250 | loss: 5.0634 | dt: 184.17ms | tok/sec: 3850.66
# GPU Memory: 5.53GB / 5.58GB
#
# step 6300 | loss: 4.6332 | dt: 181.58ms | tok/sec: 3943.81
# GPU Memory: 5.33GB / 5.42GB
#
# step 6350 | loss: 5.7308 | dt: 184.03ms | tok/sec: 4203.24
# GPU Memory: 5.59GB / 5.64GB
#
# step 6400 | loss: 4.4485 | dt: 191.51ms | tok/sec: 3947.84
# GPU Memory: 5.31GB / 5.38GB
#
# step 6450 | loss: 4.0946 | dt: 180.07ms | tok/sec: 3877.77
# GPU Memory: 5.56GB / 5.61GB
#
# Step 6500 - Sample Generation:
# Input:  I still remember the day I was elected as the
# Generated:  local park, I was thrilled to explore the world around mecha at the local park. My husband, I was thrilled at the day when I stumbled upon an avid fan of my husband, I stumbled upon an unexpected turn to me down the challenge.
#
# I've always been fascinated by my niche interest in my niche interest in my niche interest in the local community. I had never been fascinated by my love of my husband, I had to take the time to find myself scrolling through the journey.
#
#
# step 6500 | loss: 4.6343 | dt: 178.42ms | tok/sec: 3599.57
# GPU Memory: 5.24GB / 5.37GB
#
# step 6550 | loss: 4.7264 | dt: 233.54ms | tok/sec: 3683.00
# GPU Memory: 5.28GB / 5.37GB
#
# step 6600 | loss: 5.5203 | dt: 174.99ms | tok/sec: 4079.77
# GPU Memory: 5.35GB / 5.45GB
#
# step 6650 | loss: 4.2956 | dt: 187.88ms | tok/sec: 3986.95
# GPU Memory: 5.35GB / 5.46GB
#
# step 6700 | loss: 4.1451 | dt: 185.35ms | tok/sec: 3807.95
# GPU Memory: 5.17GB / 5.25GB
#
# step 6750 | loss: 4.8496 | dt: 185.14ms | tok/sec: 3957.59
# GPU Memory: 5.83GB / 5.92GB
#
# step 6800 | loss: 4.9076 | dt: 180.73ms | tok/sec: 3997.50
# GPU Memory: 5.54GB / 5.60GB
#
# step 6850 | loss: 4.7824 | dt: 172.41ms | tok/sec: 4019.72
# GPU Memory: 5.37GB / 5.49GB
#
# step 6900 | loss: 4.9262 | dt: 221.04ms | tok/sec: 4017.83
# GPU Memory: 5.26GB / 5.33GB
#
# step 6950 | loss: 4.5485 | dt: 191.93ms | tok/sec: 4015.62
# GPU Memory: 5.99GB / 6.02GB
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - loss: 4.9618 | dt: 171.96ms
# GPU Memory: 2.31GB / 5.78GB
#
# Step 7000 - Sample Generation:
# Input:  **Course Unit: Group Leader Training**
#
#
# Generated: Imagine you're playing a game where your friends are playing with friends, friends, or parents. You want to help, and you can see your parents, and your parents, you can help you and help. But what if you've heard about your friend or family, or what you've to see you. This is where you can help us understand your thoughts, feelings, or feelings to your parents.
#
# **Section 1: What is a detective?**
#
# Imagine you've heard of
#
#
# step 7000 | loss: 4.0406 | dt: 382.11ms | tok/sec: 3738.62
# GPU Memory: 3.87GB / 4.07GB
#
# step 7050 | loss: 4.7234 | dt: 181.01ms | tok/sec: 3764.50
# GPU Memory: 5.35GB / 5.45GB
#
# step 7100 | loss: 4.8327 | dt: 172.91ms | tok/sec: 3998.43
# GPU Memory: 5.26GB / 5.33GB
#
# step 7150 | loss: 4.8115 | dt: 183.06ms | tok/sec: 3974.12
# GPU Memory: 5.35GB / 5.45GB
#
# step 7200 | loss: 4.6373 | dt: 638.46ms | tok/sec: 3710.64
# GPU Memory: 5.31GB / 5.39GB
#
# step 7250 | loss: 4.1803 | dt: 178.50ms | tok/sec: 4179.52
# GPU Memory: 5.42GB / 5.46GB
#
# step 7300 | loss: 4.7172 | dt: 203.45ms | tok/sec: 3743.68
# GPU Memory: 5.28GB / 5.37GB
#
# step 7350 | loss: 4.5835 | dt: 190.23ms | tok/sec: 4114.24
# GPU Memory: 5.81GB / 5.90GB
#
# step 7400 | loss: 4.2723 | dt: 184.59ms | tok/sec: 3983.50
# GPU Memory: 5.69GB / 5.76GB
#
# step 7450 | loss: 5.3334 | dt: 175.11ms | tok/sec: 3912.39
# GPU Memory: 5.30GB / 5.39GB
#
# Step 7500 - Sample Generation:
# Input:  Course Unit: Examining the Intersection of Comics, Graphic
# Generated:  Novels, and Culture
#
# Welcome to our exploration of the fascinating world of the most intriguing concepts that will be found in this fascinating field. You might have heard of the fascinating world of art and graphic novels, specifically focusing on the fascinating world of art, which have seen the most popular genres of the most famous figures. Let us explore some key aspects of the concept of the concept of a series.
#
# **What is a Mean?**
#
# Imagine being ableism at the heart of the world
#
#
# step 7500 | loss: 4.0017 | dt: 184.86ms | tok/sec: 3907.24
# GPU Memory: 5.37GB / 5.48GB
#
# step 7550 | loss: 4.4783 | dt: 175.25ms | tok/sec: 3992.76
# GPU Memory: 5.32GB / 5.38GB
#
# step 7600 | loss: 5.3090 | dt: 219.20ms | tok/sec: 4102.82
# GPU Memory: 5.20GB / 5.28GB
#
# step 7650 | loss: 4.8686 | dt: 168.58ms | tok/sec: 3814.74
# GPU Memory: 5.14GB / 5.24GB
#
# step 7700 | loss: 4.6632 | dt: 177.29ms | tok/sec: 3963.59
# GPU Memory: 5.29GB / 5.38GB
#
# step 7750 | loss: 5.5665 | dt: 182.03ms | tok/sec: 4220.98
# GPU Memory: 5.81GB / 5.89GB
#
# step 7800 | loss: 4.5924 | dt: 172.57ms | tok/sec: 3781.20
# GPU Memory: 5.30GB / 5.38GB
#
# step 7850 | loss: 4.6532 | dt: 178.38ms | tok/sec: 4035.48
# GPU Memory: 5.45GB / 5.48GB
#
# step 7900 | loss: 5.2022 | dt: 198.23ms | tok/sec: 3901.27
# GPU Memory: 5.74GB / 5.80GB
#
# step 7950 | loss: 5.5403 | dt: 192.14ms | tok/sec: 3640.06
# GPU Memory: 5.25GB / 5.34GB
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - loss: 4.9394 | dt: 186.75ms
# GPU Memory: 2.31GB / 5.61GB
#
# Step 8000 - Sample Generation:
# Input:  Course Unit: The Roman Empire in Fiction: A
# Generated:  Look at the Lens of Modernism and the Role of Modernism
#
# In this course unit, we delve into the world of the Middle East, specifically focusing on the historical significance of the United States and the United States. This course unit delves into the world of juvenile nonfiction and its historical significance within the context of juvenile nonfiction literature and graphic novels. We will delve into how this historical context continues to provide you with a nuanced understanding of the world and challenges faced by the Middle East.
#
# 1
#
#
# step 8000 | loss: 3.8376 | dt: 250.61ms | tok/sec: 3787.33
# GPU Memory: 4.10GB / 4.27GB
#
# step 8050 | loss: 4.4555 | dt: 185.69ms | tok/sec: 3724.06
# GPU Memory: 5.29GB / 5.36GB
#
# step 8100 | loss: 4.7747 | dt: 173.89ms | tok/sec: 4021.73
# GPU Memory: 5.10GB / 5.21GB
#
# step 8150 | loss: 4.2985 | dt: 182.99ms | tok/sec: 4119.48
# GPU Memory: 5.64GB / 5.70GB
#
# step 8200 | loss: 4.7673 | dt: 211.16ms | tok/sec: 3861.45
# GPU Memory: 5.17GB / 5.25GB
#
# step 8250 | loss: 4.7101 | dt: 178.59ms | tok/sec: 4034.98
# GPU Memory: 5.26GB / 5.32GB
#
# step 8300 | loss: 4.2299 | dt: 166.17ms | tok/sec: 4066.90
# GPU Memory: 5.25GB / 5.33GB
#
# step 8350 | loss: 4.4545 | dt: 182.39ms | tok/sec: 4507.51
# GPU Memory: 5.61GB / 5.66GB
#
# step 8400 | loss: 4.9240 | dt: 175.93ms | tok/sec: 3640.63
# GPU Memory: 5.31GB / 5.39GB
#
# step 8450 | loss: 4.5625 | dt: 164.77ms | tok/sec: 3951.24
# GPU Memory: 5.09GB / 5.22GB
#
# Step 8500 - Sample Generation:
# Input:  Title: How to Use The Sibley Guide
# Generated:  to Be Your Own to Be sure to avoid distractions from your parents or family members.
#
# Step 1: Identify a Safe
#
# Step 1: Identify a successful project: Understand that your child is a successful and secure experience. This will help you understand the basics and ensure that you can be challenging.
#
# Step 2: Understand the basics of your parents: Identify your goals and weaknesses, including your child's strengths and weaknesses.
#
# Key Tip: Encourage your child to feel
#
#
# step 8500 | loss: 4.7096 | dt: 179.20ms | tok/sec: 3954.69
# GPU Memory: 5.24GB / 5.38GB
#
# step 8550 | loss: 4.7652 | dt: 190.05ms | tok/sec: 3971.27
# GPU Memory: 5.33GB / 5.41GB
#
# step 8600 | loss: 5.2203 | dt: 188.83ms | tok/sec: 3817.60
# GPU Memory: 5.99GB / 6.02GB
#
# step 8650 | loss: 5.6613 | dt: 169.35ms | tok/sec: 3731.95
# GPU Memory: 5.42GB / 5.46GB
#
# step 8700 | loss: 4.7288 | dt: 179.33ms | tok/sec: 3988.15
# GPU Memory: 5.30GB / 5.36GB
#
# step 8750 | loss: 4.6378 | dt: 175.79ms | tok/sec: 4305.80
# GPU Memory: 5.63GB / 5.69GB
#
# step 8800 | loss: 5.0809 | dt: 171.05ms | tok/sec: 3887.81
# GPU Memory: 5.44GB / 5.48GB
#
# step 8850 | loss: 4.8515 | dt: 204.48ms | tok/sec: 3699.82
# GPU Memory: 5.31GB / 5.38GB
#
# step 8900 | loss: 4.3022 | dt: 170.73ms | tok/sec: 3899.62
# GPU Memory: 5.35GB / 5.44GB
#
# step 8950 | loss: 4.4719 | dt: 179.46ms | tok/sec: 4097.46
# GPU Memory: 5.34GB / 5.43GB
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - loss: 4.7934 | dt: 170.30ms
# GPU Memory: 2.31GB / 5.57GB
#
# Step 9000 - Sample Generation:
# Input:  I recently moved to Yeovil a few years
# Generated:  ago. My friends, I was a curious and loved exploring my own unique identity. As a young girl, I was always curious about the world of the most unlikely places, so when I stumbled upon a Reddit thread where I was a Reddit thread of my life. I was a Reddit thread about my own family and I stumbled upon an old book about a Reddit thread about the past.
#
# I was a Reddit thread about the historical period, which was a Reddit thread of the "The History of
#
#
# step 9000 | loss: 4.8618 | dt: 254.71ms | tok/sec: 3850.96
# GPU Memory: 3.83GB / 3.98GB
#
# step 9050 | loss: 4.8774 | dt: 184.66ms | tok/sec: 3561.10
# GPU Memory: 5.35GB / 5.45GB
#
# step 9100 | loss: 4.3144 | dt: 237.41ms | tok/sec: 3659.60
# GPU Memory: 5.41GB / 5.44GB
#
# step 9150 | loss: 4.7032 | dt: 179.52ms | tok/sec: 4024.79
# GPU Memory: 5.60GB / 5.64GB
#
# step 9200 | loss: 3.9548 | dt: 183.74ms | tok/sec: 3903.18
# GPU Memory: 5.21GB / 5.27GB
#
# step 9250 | loss: 5.3175 | dt: 173.87ms | tok/sec: 4265.97
# GPU Memory: 5.45GB / 5.49GB
#
# step 9300 | loss: 3.3356 | dt: 174.35ms | tok/sec: 3890.58
# GPU Memory: 5.19GB / 5.27GB
#
# step 9350 | loss: 4.3773 | dt: 182.54ms | tok/sec: 3777.65
# GPU Memory: 5.32GB / 5.40GB
#
# step 9400 | loss: 4.6809 | dt: 173.87ms | tok/sec: 3886.62
# GPU Memory: 5.41GB / 5.45GB
#
# step 9450 | loss: 4.2975 | dt: 175.23ms | tok/sec: 3997.78
# GPU Memory: 5.24GB / 5.30GB
#
# Step 9500 - Sample Generation:
# Input:  Course Unit: Enlightenment Values in French Literature - Un
# Generated: raveling in the Middle Ages
#
# In this course unit, we will explore the concept of the United States and the role of the Christian beliefs about Jesus Christ's involvement in the United States. We will examine how the author of the "The World" and the "Race & Class" in the United States. We will examine the historical context, its significance, and contemporary relevance. We will also examine how these stories can be traced back to the 197th century. We will also
#
#
# step 9500 | loss: 5.1068 | dt: 205.39ms | tok/sec: 3852.88
# GPU Memory: 5.86GB / 6.04GB
#
# step 9550 | loss: 4.0633 | dt: 173.45ms | tok/sec: 3934.90
# GPU Memory: 5.48GB / 5.51GB
#
# step 9600 | loss: 4.8030 | dt: 178.11ms | tok/sec: 4142.49
# GPU Memory: 5.58GB / 5.62GB
#
# step 9650 | loss: 4.4450 | dt: 173.44ms | tok/sec: 4030.17
# GPU Memory: 5.29GB / 5.36GB
#
# step 9700 | loss: 4.0842 | dt: 177.04ms | tok/sec: 4275.76
# GPU Memory: 5.42GB / 5.45GB
#
# step 9750 | loss: 4.2598 | dt: 239.85ms | tok/sec: 3955.86
# GPU Memory: 5.19GB / 5.28GB
#
# step 9800 | loss: 4.2879 | dt: 162.08ms | tok/sec: 4308.44
# GPU Memory: 5.01GB / 5.18GB
#
# step 9850 | loss: 5.1025 | dt: 175.22ms | tok/sec: 4155.82
# GPU Memory: 5.52GB / 5.57GB
#
# step 9900 | loss: 4.5045 | dt: 187.34ms | tok/sec: 3960.34
# GPU Memory: 5.37GB / 5.48GB
#
# step 9950 | loss: 5.2817 | dt: 171.27ms | tok/sec: 3936.73
# GPU Memory: 5.25GB / 5.33GB
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - loss: 4.7128 | dt: 179.87ms
# GPU Memory: 2.31GB / 5.74GB
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/loops/optimization/automatic.py:134: `training_step` returned `None`. If this was on purpose, ignore this warning...
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - loss: 4.7145 | dt: 284.08ms
# GPU Memory: 2.31GB / 6.30GB
# INFO:pytorch_lightning.profilers.profiler:FIT Profiler Report
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                                   	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                                    	|  -              	|  378118         	|  6227.2         	|  100 %          	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                                       	|  6197.5         	|  1              	|  6197.5         	|  99.523         	|
# |  run_training_batch                                                                                                                                                       	|  0.46688        	|  10001          	|  4669.2         	|  74.981         	|
# |  [LightningModule]LitDeepSeekLM.optimizer_step                                                                                                                            	|  0.49674        	|  5000           	|  2483.7         	|  39.885         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                             	|  0.20928        	|  10001          	|  2093.0         	|  33.61          	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                                  	|  0.20391        	|  10000          	|  2039.1         	|  32.745         	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_batch_end       	|  0.12329        	|  10001          	|  1233.0         	|  19.801         	|
# |  save_checkpoint                                                                                                                                                          	|  72.494         	|  17             	|  1232.4         	|  19.79          	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                           	|  0.16913        	|  1102           	|  186.39         	|  2.9931         	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                                               	|  0.0079526      	|  10001          	|  79.534         	|  1.2772         	|
# |  [LightningModule]LitDeepSeekLM.configure_gradient_clipping                                                                                                               	|  0.0024502      	|  5000           	|  12.251         	|  0.19673        	|
# |  [_EvaluationLoop].val_next                                                                                                                                               	|  0.0099166      	|  1102           	|  10.928         	|  0.17549        	|
# |  [LightningModule]LitDeepSeekLM.optimizer_zero_grad                                                                                                                       	|  0.00092573     	|  5001           	|  4.6296         	|  0.074344       	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                           	|  0.00018744     	|  11103          	|  2.0812         	|  0.03342        	|
# |  [LightningDataModule]CosmopediaDataModule.setup                                                                                                                          	|  1.8316         	|  1              	|  1.8316         	|  0.029413       	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                                                                                                                             	|  0.00015482     	|  10001          	|  1.5484         	|  0.024865       	|
# |  [LightningModule]LitDeepSeekLM.transfer_batch_to_device                                                                                                                  	|  0.0001272      	|  11103          	|  1.4122         	|  0.022679       	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                            	|  0.039412       	|  12             	|  0.47294        	|  0.0075947      	|
# |  [Callback]LearningRateMonitor.on_train_batch_start                                                                                                                       	|  4.1202e-05     	|  10001          	|  0.41206        	|  0.0066171      	|
# |  [LightningModule]LitDeepSeekLM.on_train_batch_end                                                                                                                        	|  3.7173e-05     	|  10001          	|  0.37177        	|  0.0059701      	|
# |  [LightningModule]LitDeepSeekLM.lr_scheduler_step                                                                                                                         	|  3.0517e-05     	|  5000           	|  0.15259        	|  0.0024503      	|
# |  [LightningModule]LitDeepSeekLM.configure_optimizers                                                                                                                      	|  0.05625        	|  1              	|  0.05625        	|  0.00090329     	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                        	|  5.0513e-05     	|  1102           	|  0.055665       	|  0.00089389     	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                                      	|  4.3824e-05     	|  1102           	|  0.048294       	|  0.00077552     	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                              	|  0.0036362      	|  12             	|  0.043634       	|  0.00070069     	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                                 	|  0.041771       	|  1              	|  0.041771       	|  0.00067078     	|
# |  [LightningModule]LitDeepSeekLM.on_validation_model_eval                                                                                                                  	|  0.0034757      	|  12             	|  0.041708       	|  0.00066977     	|
# |  [Callback]LearningRateMonitor.on_after_backward                                                                                                                          	|  3.8078e-06     	|  10000          	|  0.038078       	|  0.00061148     	|
# |  [Callback]LearningRateMonitor.on_before_backward                                                                                                                         	|  2.8344e-06     	|  10000          	|  0.028344       	|  0.00045516     	|
# |  [Callback]LearningRateMonitor.on_train_batch_end                                                                                                                         	|  2.8258e-06     	|  10001          	|  0.028261       	|  0.00045382     	|
# |  [LightningModule]LitDeepSeekLM.on_validation_model_zero_grad                                                                                                             	|  0.0026351      	|  10             	|  0.026351       	|  0.00042316     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                          	|  0.023167       	|  1              	|  0.023167       	|  0.00037203     	|
# |  [Callback]TQDMProgressBar.on_train_batch_start                                                                                                                           	|  1.9479e-06     	|  10001          	|  0.019481       	|  0.00031284     	|
# |  [Callback]LearningRateMonitor.on_before_optimizer_step                                                                                                                   	|  3.6393e-06     	|  5000           	|  0.018196       	|  0.00029221     	|
# |  [LightningModule]LitDeepSeekLM.on_before_batch_transfer                                                                                                                  	|  1.4901e-06     	|  11103          	|  0.016544       	|  0.00026568     	|
# |  [Callback]ModelSummary.on_train_batch_end                                                                                                                                	|  1.5544e-06     	|  10001          	|  0.015546       	|  0.00024964     	|
# |  [Callback]LearningRateMonitor.on_before_zero_grad                                                                                                                        	|  3.0636e-06     	|  5001           	|  0.015321       	|  0.00024604     	|
# |  [LightningModule]LitDeepSeekLM.on_after_batch_transfer                                                                                                                   	|  1.2828e-06     	|  11103          	|  0.014243       	|  0.00022873     	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                                      	|  0.014024       	|  1              	|  0.014024       	|  0.00022521     	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                              	|  1.3265e-06     	|  10000          	|  0.013265       	|  0.00021301     	|
# |  [LightningModule]LitDeepSeekLM.on_after_backward                                                                                                                         	|  1.2438e-06     	|  10000          	|  0.012438       	|  0.00019973     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_batch_start     	|  1.2259e-06     	|  10001          	|  0.01226        	|  0.00019687     	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                             	|  1.1779e-06     	|  10000          	|  0.011779       	|  0.00018916     	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                                	|  1.1207e-06     	|  10000          	|  0.011207       	|  0.00017997     	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                                 	|  1.1121e-06     	|  10000          	|  0.011121       	|  0.00017858     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_before_backward       	|  1.1006e-06     	|  10000          	|  0.011006       	|  0.00017674     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_after_backward        	|  1.0968e-06     	|  10000          	|  0.010968       	|  0.00017614     	|
# |  [LightningModule]LitDeepSeekLM.on_before_backward                                                                                                                        	|  1.0594e-06     	|  10000          	|  0.010594       	|  0.00017013     	|
# |  [Callback]ModelSummary.on_train_batch_start                                                                                                                              	|  1.049e-06      	|  10001          	|  0.010491       	|  0.00016848     	|
# |  [LightningModule]LitDeepSeekLM.on_train_batch_start                                                                                                                      	|  1.0089e-06     	|  10001          	|  0.01009        	|  0.00016204     	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                                      	|  8.4427e-07     	|  10001          	|  0.0084436      	|  0.00013559     	|
# |  [Callback]LearningRateMonitor.on_validation_batch_end                                                                                                                    	|  7.6346e-06     	|  1102           	|  0.0084134      	|  0.00013511     	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                                       	|  1.3586e-06     	|  5000           	|  0.0067931      	|  0.00010909     	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                            	|  1.3111e-06     	|  5001           	|  0.0065567      	|  0.00010529     	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                          	|  1.1992e-06     	|  5000           	|  0.0059962      	|  9.629e-05      	|
# |  [LightningModule]LitDeepSeekLM.on_before_optimizer_step                                                                                                                  	|  1.1683e-06     	|  5000           	|  0.0058415      	|  9.3806e-05     	|
# |  [LightningModule]LitDeepSeekLM.on_before_zero_grad                                                                                                                       	|  1.1383e-06     	|  5001           	|  0.0056927      	|  9.1417e-05     	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                               	|  1.106e-06      	|  5001           	|  0.0055312      	|  8.8822e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_before_zero_grad      	|  1.0592e-06     	|  5001           	|  0.0052969      	|  8.506e-05      	|
# ...
# |  [Callback]LearningRateMonitor.on_validation_start                                                                                                                        	|  3.3534e-06     	|  12             	|  4.0241e-05     	|  6.4621e-07     	|
# |  [LightningDataModule]CosmopediaDataModule.state_dict                                                                                                                     	|  2.14e-06       	|  17             	|  3.638e-05      	|  5.8421e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_epoch_end       	|  2.7484e-05     	|  1              	|  2.7484e-05     	|  4.4135e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_save_checkpoint       	|  1.6115e-06     	|  17             	|  2.7396e-05     	|  4.3994e-07     	|
# |  [Callback]LearningRateMonitor.on_validation_epoch_start                                                                                                                  	|  1.9775e-06     	|  12             	|  2.373e-05      	|  3.8107e-07     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                             	|  1.2906e-06     	|  17             	|  2.1941e-05     	|  3.5234e-07     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                                       	|  1.7479e-06     	|  12             	|  2.0975e-05     	|  3.3683e-07     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                            	|  1.9995e-05     	|  1              	|  1.9995e-05     	|  3.2109e-07     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                                      	|  1.6437e-06     	|  12             	|  1.9724e-05     	|  3.1674e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_start      	|  1.6338e-06     	|  12             	|  1.9606e-05     	|  3.1484e-07     	|
# |  [LightningModule]LitDeepSeekLM.on_validation_start                                                                                                                       	|  1.5727e-06     	|  12             	|  1.8872e-05     	|  3.0306e-07     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                        	|  1.4636e-06     	|  12             	|  1.7563e-05     	|  2.8204e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_epoch_start	|  1.3551e-06     	|  12             	|  1.6261e-05     	|  2.6113e-07     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                         	|  1.347e-06      	|  12             	|  1.6164e-05     	|  2.5957e-07     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                           	|  1.3424e-06     	|  12             	|  1.6109e-05     	|  2.5869e-07     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                         	|  1.3419e-06     	|  12             	|  1.6103e-05     	|  2.5859e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_epoch_end  	|  1.2959e-06     	|  12             	|  1.5551e-05     	|  2.4973e-07     	|
# |  [LightningModule]LitDeepSeekLM.on_validation_epoch_end                                                                                                                   	|  1.2843e-06     	|  12             	|  1.5411e-05     	|  2.4748e-07     	|
# |  [LightningModule]LitDeepSeekLM.on_validation_epoch_start                                                                                                                 	|  1.2524e-06     	|  12             	|  1.5029e-05     	|  2.4134e-07     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                                	|  8.5688e-07     	|  17             	|  1.4567e-05     	|  2.3392e-07     	|
# |  [LightningModule]LitDeepSeekLM.on_train_epoch_end                                                                                                                        	|  1.3342e-05     	|  1              	|  1.3342e-05     	|  2.1425e-07     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                                    	|  7.32e-06       	|  1              	|  7.32e-06       	|  1.1755e-07     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                          	|  6.754e-06      	|  1              	|  6.754e-06      	|  1.0846e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_start           	|  6.047e-06      	|  1              	|  6.047e-06      	|  9.7106e-08     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_fit_start             	|  5.89e-06       	|  1              	|  5.89e-06       	|  9.4584e-08     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                             	|  5.192e-06      	|  1              	|  5.192e-06      	|  8.3376e-08     	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                                	|  4.749e-06      	|  1              	|  4.749e-06      	|  7.6262e-08     	|
# |  [Callback]LearningRateMonitor.on_fit_start                                                                                                                               	|  4.125e-06      	|  1              	|  4.125e-06      	|  6.6241e-08     	|
# |  [Callback]LearningRateMonitor.on_fit_end                                                                                                                                 	|  3.952e-06      	|  1              	|  3.952e-06      	|  6.3463e-08     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                              	|  3.875e-06      	|  1              	|  3.875e-06      	|  6.2227e-08     	|
# |  [LightningModule]LitDeepSeekLM.configure_callbacks                                                                                                                       	|  3.86e-06       	|  1              	|  3.86e-06       	|  6.1986e-08     	|
# |  [Callback]LearningRateMonitor.on_train_epoch_start                                                                                                                       	|  3.818e-06      	|  1              	|  3.818e-06      	|  6.1311e-08     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                                      	|  3.479e-06      	|  1              	|  3.479e-06      	|  5.5867e-08     	|
# |  [Callback]LearningRateMonitor.on_sanity_check_end                                                                                                                        	|  3.442e-06      	|  1              	|  3.442e-06      	|  5.5273e-08     	|
# |  [Callback]LearningRateMonitor.on_train_epoch_end                                                                                                                         	|  3.323e-06      	|  1              	|  3.323e-06      	|  5.3362e-08     	|
# |  [Callback]LearningRateMonitor.setup                                                                                                                                      	|  3.201e-06      	|  1              	|  3.201e-06      	|  5.1403e-08     	|
# |  [Callback]LearningRateMonitor.on_sanity_check_start                                                                                                                      	|  2.864e-06      	|  1              	|  2.864e-06      	|  4.5991e-08     	|
# |  [Callback]LearningRateMonitor.on_train_end                                                                                                                               	|  2.777e-06      	|  1              	|  2.777e-06      	|  4.4594e-08     	|
# |  [Callback]LearningRateMonitor.teardown                                                                                                                                   	|  2.646e-06      	|  1              	|  2.646e-06      	|  4.2491e-08     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                                   	|  1.99e-06       	|  1              	|  1.99e-06       	|  3.1956e-08     	|
# |  [LightningModule]LitDeepSeekLM.setup                                                                                                                                     	|  1.874e-06      	|  1              	|  1.874e-06      	|  3.0094e-08     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                                       	|  1.866e-06      	|  1              	|  1.866e-06      	|  2.9965e-08     	|
# |  [LightningDataModule]CosmopediaDataModule.teardown                                                                                                                       	|  1.828e-06      	|  1              	|  1.828e-06      	|  2.9355e-08     	|
# |  [LightningModule]LitDeepSeekLM.on_fit_start                                                                                                                              	|  1.79e-06       	|  1              	|  1.79e-06       	|  2.8745e-08     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_sanity_check_start    	|  1.775e-06      	|  1              	|  1.775e-06      	|  2.8504e-08     	|
# |  [LightningModule]LitDeepSeekLM.on_fit_end                                                                                                                                	|  1.752e-06      	|  1              	|  1.752e-06      	|  2.8134e-08     	|
# |  [Callback]ModelSummary.setup                                                                                                                                             	|  1.72e-06       	|  1              	|  1.72e-06       	|  2.7621e-08     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                               	|  1.669e-06      	|  1              	|  1.669e-06      	|  2.6802e-08     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                          	|  1.576e-06      	|  1              	|  1.576e-06      	|  2.5308e-08     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.teardown                 	|  1.498e-06      	|  1              	|  1.498e-06      	|  2.4056e-08     	|
# |  [LightningModule]LitDeepSeekLM.on_train_epoch_start                                                                                                                      	|  1.494e-06      	|  1              	|  1.494e-06      	|  2.3991e-08     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_epoch_start     	|  1.477e-06      	|  1              	|  1.477e-06      	|  2.3718e-08     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                                     	|  1.414e-06      	|  1              	|  1.414e-06      	|  2.2707e-08     	|
# |  [LightningModule]LitDeepSeekLM.on_train_start                                                                                                                            	|  1.318e-06      	|  1              	|  1.318e-06      	|  2.1165e-08     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_fit_end               	|  1.305e-06      	|  1              	|  1.305e-06      	|  2.0956e-08     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                        	|  1.296e-06      	|  1              	|  1.296e-06      	|  2.0812e-08     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_sanity_check_end      	|  1.287e-06      	|  1              	|  1.287e-06      	|  2.0667e-08     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                            	|  1.262e-06      	|  1              	|  1.262e-06      	|  2.0266e-08     	|
# |  [LightningModule]LitDeepSeekLM.teardown                                                                                                                                  	|  1.165e-06      	|  1              	|  1.165e-06      	|  1.8708e-08     	|
# |  [Callback]ModelCheckpoint{'monitor': 'train_loss', 'mode': 'min', 'every_n_train_steps': 500, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_end             	|  1.11e-06       	|  1              	|  1.11e-06       	|  1.7825e-08     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                              	|  9.86e-07       	|  1              	|  9.86e-07       	|  1.5834e-08     	|
# |  [LightningModule]LitDeepSeekLM.on_train_end                                                                                                                              	|  9.42e-07       	|  1              	|  9.42e-07       	|  1.5127e-08     	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Generating learning rate plot...
# Learning rate plot saved as 'learning_rate_schedule.png'

# %% [markdown]
# ---
#
# ## Inference

# %%
from deepseek_inference import generate_text, load_model

# Path to your checkpoint
checkpoint_path = "./checkpoints/last.ckpt"

# Load the model
model = load_model(checkpoint_path)
print("Model loaded successfully!")

# Example prompts for generation
prompts = [
    "Once upon a time",
    "The future of artificial intelligence",
    "In the distant galaxy",
    "He was walking",
    "Music is a"
]

# Generate text for each prompt
for prompt in prompts:
    print("\nPrompt:", prompt)
    generated = generate_text(prompt=prompt, model=model)
    print("Generated:", generated)
    print("-" * 50)
# Out:
# Compiling model for faster training...
# Model size in memory: 1327.85 MB
# Model loaded successfully!
#
# Prompt: Once upon a time
# Generated: Once upon a time, in a small town named Harmonyville, lived two best friends - Timmy the Mr. Johnson, Timmy the Turtle, the Tortoise, the professor, and Benny the Scientist, they decided to share their thoughts with the park. One day, they heard some exciting news!
#
# Curious about all the different stories they met "I'm one of a little town. When they entered, they could visit the park to watch new things like where they come from all the animals they would get better and better
# --------------------------------------------------
#
# Prompt: The future of artificial intelligence
# Generated: The future of artificial intelligence, a special tool that provides an in high-quality design, and converting it into manageable parts. This is characterized by its high vision of a suitable area of materials available to a set of advantages and limitations. It is used to apply this method to play in the field of online gaming. By the end of this unit, you will be able to optimize this new language.
#
# ### Step 1: Understanding Your Body
#
# To begin exploring the basics of BHS, let's first understand
# --------------------------------------------------
#
# Prompt: In the distant galaxy
# Generated: In the distant galaxy, the bustling city of Stell, the U. Captain was always eager to become a prominent figure, who had been passionate about his friendship with a place in Canada. He had been the first few years, but she couldn't help but think about all the world around him.
#
# "Hey, what do you know?" asked Polly. "The rhythm of the Way of Post-Just like many people because people can't want them to meet. One day, they shared a crucial role in
# --------------------------------------------------
#
# Prompt: He was walking
# Generated: He was walking on a journey. It was a new way of saying, "What do you do?." It would be pretty cool, right? It's all about going on!
#
# Max looked at the middle of the West"I've learned about "What do people do today?" she asked, "Well, why do people talk about different ways to use physical activities, which are important for everyone to wear and talk to others, even when they go away or try out with them to understand your emotions
# --------------------------------------------------
#
# Prompt: Music is a
# Generated: Music is a fundamental aspect of a system. It provides an image with a wide range of data, which are a type of numbers that creates a range of times, which is known as the "tune behavior." This is a type of activity that allows us to understand a lot, shape, and texture and shape, shape and shape. It allows us to determine how a signal is applied to measure the effect of the image.
#
# Let's start with the concept of an example. Imagine you want to know that
# --------------------------------------------------
